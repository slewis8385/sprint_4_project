# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('../vehicles_us.csv')
df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
# ...

# %%
duplicates = df.duplicated().sum()
duplicates
# Out:
# 0

# %%
df.info()
df.describe()
unique_values_vehicles = df.nunique()
display(unique_values_vehicles)
missing_values_vehicles= df.isnull().sum()
display(missing_values_vehicles)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
# price            3443
# model_year         68
# model             100
# condition           6
# cylinders           7
# fuel                5
# ...

# %%
df.fillna('unknown', inplace=True)
display(df.head(7))
#what should I fill these missing values with
# Out:
# C:\Users\lewis\AppData\Local\Temp\ipykernel_13612\1768649617.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('unknown', inplace=True)
#    price model_year           model  condition cylinders fuel  odometer  \
# 0   9400     2011.0          bmw x5       good       6.0  gas  145000.0
# 1  25500    unknown      ford f-150       good       6.0  gas   88705.0
# 2   5500     2013.0  hyundai sonata   like new       4.0  gas  110000.0
# 3   1500     2003.0      ford f-150       fair       8.0  gas   unknown
# 4  14900     2017.0    chrysler 200  excellent       4.0  gas   80903.0
# 5  14990     2014.0    chrysler 300  excellent       6.0  gas   57954.0
# 6  12990     2015.0    toyota camry  excellent       4.0  gas   79212.0
#
# ...

# %%
df.head()
# Out:
#    price model_year           model  condition cylinders fuel  odometer  \
# 0   9400     2011.0          bmw x5       good       6.0  gas  145000.0
# 1  25500    unknown      ford f-150       good       6.0  gas   88705.0
# 2   5500     2013.0  hyundai sonata   like new       4.0  gas  110000.0
# 3   1500     2003.0      ford f-150       fair       8.0  gas   unknown
# 4  14900     2017.0    chrysler 200  excellent       4.0  gas   80903.0
#
#   transmission    type paint_color   is_4wd date_posted  days_listed
# 0    automatic     SUV     unknown      1.0   6/23/2018           19
# 1    automatic  pickup       white      1.0  10/19/2018           50
# 2    automatic   sedan         red  unknown    2/7/2019           79
# 3    automatic  pickup     unknown  unknown   3/22/2019            9
# 4    automatic   sedan       black  unknown    4/2/2019           28

# %%
fig = px.histogram(df, x='model')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 fig = px.histogram(df, x='model')
#       2 fig.show()
#
# AttributeError: module 'plotly.express' has no attribute 'histogram'

# %%
fig = px.scatter(data_frame=df, x='model', y='price', title='Price vs. Model')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 fig = px.scatter(data_frame=df, x='model', y='price', title='Price vs. Model')
#       2 fig.show()
#
# AttributeError: module 'plotly.express' has no attribute 'scatter'
